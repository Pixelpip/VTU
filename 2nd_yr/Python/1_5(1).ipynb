# %% [markdown]
# 1)A)

# %%
m1 = int(input("Enter the marks in the first test: "))
m2 = int(input("Enter the marks in the second test: "))
m3 = int(input("Enter the marks in the third test: "))

if m1 <= m2 and m1 <= m3:  # m1 is smaller
    total = m2 + m3
elif m2 <= m1 and m2 <= m3:  # m2 is smaller
    total = m1 + m3
else:  # m3 is smaller
    total = m1 + m2

avg = total / 2
print("The average of the best two test marks is:", avg)
# Out:
# Enter the marks in the first test: 10
# Enter the marks in the second test: 20
# Enter the marks in the third test: 30
# The average of the best two test marks is: 25.0

# %% [markdown]
# 1)B)

# %%
val = input("Enter numbers only: ")
if val == val[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")

for i in range(10):
    if val.count(str(i)) > 0:
        print(str(i), "appears", val.count(str(i)), "times")
# Out:
# Enter numbers only: 1221
# Palindrome
# 1 appears 2 times
# 2 appears 2 times

# %% [markdown]
# 2)A)

# %%
def fn(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return fn(n-1) + fn(n-2)

num = int(input("Enter a number: "))
if num > 0:
    print("fn(", num, ") = ", fn(num))
else:
    print("Error in input")
# Out:
# Enter a number: 10
# fn( 10 ) =  34

# %% [markdown]
# 2)b) Binary to decimal

# %%
def bin2Dec(val):
    rev = val[::-1]
    dec = 0
    i = 0
    for dig in rev:
        dec = dec + int(dig) * 2**i
        i = i + 1
    return dec

num1 = input("Enter a binary number: ")
print('The decimal number is', bin2Dec(num1))
# Out:
# Enter a binary number: 1001
# The decimal number is 9

# %% [markdown]
# 2)b)Octal to hexadecimal

# %%
def oct2hex(octal):
    dec = 0
    i = 0

    # Converting octal to decimal
    while octal != 0:
        dec += (octal % 10) * (8 ** i)  # Multiply the last digit with 8 raised to the power of its position
        octal //= 10  # Integer division to remove the last digit
        i += 1

    # Converting decimal to hexadecimal
    hex_digits = []
    while dec != 0:
        hex_digits.append(dec % 16)  # Get the remainder when divided by 16
        dec //= 16  # Integer division to get the next quotient

    # Map the hexadecimal digits to their respective characters
    hexa = ""
    for elem in hex_digits[::-1]:
        if elem <= 9:
            hexa += str(elem)  # Append digits 0-9 as they are
        else:
            hexa += chr(ord('A') + (elem - 10))  # Convert digits 10-15 to their corresponding hexadecimal characters

    return hexa

# Input octal number
octal_num = int(input("Enter an octal number: "))
hexadecimal_result = oct2hex(octal_num)
print(f"Hexadecimal equivalent: {hexadecimal_result}")
# Out:
# Enter an octal number: 245
# Hexadecimal equivalent: A5

# %% [markdown]
# 3)a)

# %%
sentence = input("Enter a sentence: ")
wordList = sentence.split(" ")
print("This sentence has", len(wordList), "words")

digCnt = upCnt = loCnt = 0

for ch in sentence:
    if '0' <= ch <= '9':
        digCnt += 1
    elif 'A' <= ch <= 'Z':
        upCnt += 1
    elif 'a' <= ch <= 'z':
        loCnt += 1

print("This sentence has", digCnt, "digits,", upCnt, "uppercase letters,", loCnt, "lowercase letters")
# Out:
# Enter a sentence: YeshYemVeeAyeTeaYem Paaroud Moment
# This sentence has 3 words
# This sentence has 0 digits, 8 uppercase letters, 24 lowercase letters

# %% [markdown]
# 3)b)

# %%
str1 = input("Enter String 1:\n")
str2 = input("Enter String 2:\n")

if len(str2) < len(str1):
    short = len(str2)
    long = len(str1)
else:
    short = len(str1)
    long = len(str2)

matchCnt = 0

for i in range(short):
    if str1[i] == str2[i]:
        matchCnt += 1

print("Similarity between the two strings:")
print((matchCnt / long) * 100, "%")
# Out:
# Enter String 1:
# welcome to computer science
# Enter String 2:
# welcome to computer network
# Similarity between the two strings:
# 74.07407407407408 %

# %% [markdown]
# 4)a)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %% [markdown]
# 4)b)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94
,78,77,85,86])
plt.scatter(x, y,color="red")
plt.show()

# %% [markdown]
# 5)a)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for the histogram
data = np.random.randn(1000)
# Plotting a basic histogram
plt.hist(data, bins=30, color='skyblue',
edgecolor='black')
# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Generate random 2D data for hexbin plot
x = np.random.randn(1000)
y = 2 * x + np.random.normal(size=1000)
# Creating a 2D histogram (hexbin plot)
plt.hexbin(x, y,gridsize=40,cmap="Blues")
# Adding labels and title
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('2D Histogram (Hexbin Plot)')
# Adding colorbar
plt.colorbar()
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for stacked histograms
data1 = np.random.randn(1000)
data2 = np.random.randn(1000)
# Creating a stacked histogram
plt.hist([data1, data2],bins=30,stacked=True,color=['cyan', 'Purple'],edgecolor='black')
# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')
# Adding legend
plt.legend(['Dataset 1', 'Dataset 2'])
# Display the plot
plt.show()

# %% [markdown]
# 5)b)

# %%
from matplotlib import pyplot as plt
import numpy as np
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
'TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]
# Creating plot
#fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
# show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
sizes = [20, 30, 40, 10]
labels = ['A', 'B', 'C', 'D']

# Creating the pie chart with percentage labels
plt.pie(sizes, labels=labels, autopct='%1.4f%%')
plt.title('Pie Chart with Percentage')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
sizes = [20, 30, 40, 10]
labels = ['A', 'B', 'C', 'D']
explode=(0,0.1,0,0)

# Creating the pie chart with percentage labels
plt.pie(sizes,explode=explode,labels=labels, autopct='%1.4f%%')
plt.title('Pie Chart with Percentage')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
sizes = [20, 30, 40, 10]
labels = ['A', 'B', 'C', 'D']
explode=(0,0.1,0,0)

# Creating the pie chart with percentage labels
plt.pie(sizes,explode=explode,labels=labels, autopct='%1.4f%%',counterclock=False,startangle=90)
plt.title('Pie Chart with Percentage')

# Display the pie chart
plt.show()
